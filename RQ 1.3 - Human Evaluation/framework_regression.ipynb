# %% [markdown]
# # Regression for RQ 1.3
# In this notebook, regression on the human evaluation data from RQ 1.3 is performed. That way, we can see if the toxicity score and the rate of profanity have a meaningful relation with the severeness category. First, the severeness variable is mapped to the numbers 0, 1, 2, 3 to enable linear regression. Then, the linear regression is performed.

# %%
import pandas as pd
import statsmodels.api as sm

file_path = 'output_for_regression.csv'
data = pd.read_csv(file_path)

data['Severeness_Encoded'] = data['Severeness'].map({'Non-toxic': 0,'Low': 1, 'Medium': 2, 'High': 3})

# %%
data
# Out:
#      Toxicity Score  Ratio of profanity Severeness  Severeness_Encoded
# 0          0.787120            0.022222        Low                   1
# 1          0.782071            0.026316        Low                   1
# 2          0.956375            0.131579       High                   3
# 3          0.829959            0.133333     Medium                   2
# 4          0.572712            0.083333     Medium                   2
# ..              ...                 ...        ...                 ...
# 98         0.658813            0.029412        Low                   1
# 99         0.944597            0.000000        Low                   1
# 100        0.956375            0.290323     Medium                   2
# 101        0.770145            0.052632        Low                   1
# 102        0.751094            0.000000     Medium                   2
#
# [103 rows x 4 columns]

# %%
X = data[['Toxicity Score', 'Ratio of profanity']]
y = data['Severeness_Encoded']                     

X_with_const = sm.add_constant(X)

model = sm.OLS(y, X_with_const)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Severeness_Encoded   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     16.93
# Date:                Tue, 21 Jan 2025   Prob (F-statistic):           4.66e-07
# Time:                        16:04:52   Log-Likelihood:                -102.80
# No. Observations:                 103   AIC:                             211.6
# Df Residuals:                     100   BIC:                             219.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.2692      0.421     -0.640      0.524      -1.104       0.566
# ...
